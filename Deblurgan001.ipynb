# %% [markdown]
# <a href="https://colab.research.google.com/github/riku12489520/Deblurgan001/blob/master/Deblurgan001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile

zf = zipfile.ZipFile("/content/drive/My Drive/GOPRO_Large.zip 的副本")
zf.extractall("/content/Deblurgan001")

# %%
# %cd /content/deblur-gan/
# !pip install -r requirements-gpu.txt

# %%
# %cd /content/deblur-gan
# !python organize_gopro_dataset.py --dir_in=GOPRO_Large --dir_out=images

# %%
# !python train.py --n_images=512 --batch_size=4

# %%
# !python test.py

# %%
# !python deblur_image.py --image_path=7.jpg

# %%
# !pwd
# Out:
# /content/deblur-gan
